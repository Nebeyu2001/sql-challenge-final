# %%
# Dependencies and Setup
import pandas as pd
import matplotlib.pyplot as plt
from config import username,password

# %%
from sqlalchemy import create_engine

# %%
# create Engine for the project database
engine = create_engine(f'postgresql://{username}:{password}@localhost:5432/project_db')
connection = engine.connect()

# %%
# Query All Records in the the employees Table
emp_df=pd.read_sql("Select * from employees",connection)
emp_df
# Out:
#         emp_no emp_title_id  birth_date   first_name  last_name sex  \
# 0       473302        s0001  1953-07-25     Hideyuki   Zallocco   M
# 1       475053        e0002  1954-11-18        Byong  Delgrande   F
# 2        57444        e0002  1958-01-30        Berry       Babb   F
# 3       421786        s0001  1957-09-28        Xiong   Verhoeff   M
# 4       282238        e0003  1952-10-28   Abdelkader    Baumann   F
# ...        ...          ...         ...          ...        ...  ..
# 300019  464231        s0001  1958-08-14  Constantino    Eastman   M
# 300020  255832        e0002  1955-05-08       Yuping     Dayang   F
# 300021   76671        s0001  1959-06-09       Ortrud   Plessier   M
# 300022  264920        s0001  1959-09-22        Percy   Samarati   F
# 300023  464503        s0002  1964-05-31       Arvind  Slobodova   M
#
#          hire_date
# 0       1990-04-28
# 1       1991-09-07
# 2       1992-03-21
# 3       1987-11-26
# 4       1991-01-18
# ...            ...
# ...

# %%
# # Query All Records in the Salaries Table
salary_df=pd.read_sql("Select * from salaries",connection)
salary_df
# Out:
#         emp_no  salary
# 0        10001   60117
# 1        10002   65828
# 2        10003   40006
# 3        10004   40054
# 4        10005   78228
# ...        ...     ...
# 300019  499995   40000
# 300020  499996   58058
# 300021  499997   49597
# 300022  499998   40000
# 300023  499999   63707
#
# [300024 rows x 2 columns]

# %%
# Query All Records in the titles Table
titles_df=pd.read_sql("Select * from titles",connection)
titles_df
# Out:
#   title_id               title
# 0    s0001               Staff
# 1    s0002        Senior Staff
# 2    e0001  Assistant Engineer
# 3    e0002            Engineer
# 4    e0003     Senior Engineer
# 5    e0004    Technique Leader
# 6    m0001             Manager

# %%
titles_df.rename(columns={"title_id":"emp_title_id"},inplace=True)

# %%
# merge and combine all the tables
merge_df=pd.merge(emp_df,salary_df, on="emp_no" )
merge_df
# Out:
#         emp_no emp_title_id  birth_date   first_name  last_name sex  \
# 0       473302        s0001  1953-07-25     Hideyuki   Zallocco   M
# 1       475053        e0002  1954-11-18        Byong  Delgrande   F
# 2        57444        e0002  1958-01-30        Berry       Babb   F
# 3       421786        s0001  1957-09-28        Xiong   Verhoeff   M
# 4       282238        e0003  1952-10-28   Abdelkader    Baumann   F
# ...        ...          ...         ...          ...        ...  ..
# 300019  464231        s0001  1958-08-14  Constantino    Eastman   M
# 300020  255832        e0002  1955-05-08       Yuping     Dayang   F
# 300021   76671        s0001  1959-06-09       Ortrud   Plessier   M
# 300022  264920        s0001  1959-09-22        Percy   Samarati   F
# 300023  464503        s0002  1964-05-31       Arvind  Slobodova   M
#
#          hire_date  salary
# 0       1990-04-28   40000
# 1       1991-09-07   53422
# 2       1992-03-21   48973
# 3       1987-11-26   40000
# ...

# %%
final_merge_df=pd.merge(merge_df,titles_df,on="emp_title_id")
final_merge_df
# Out:
#         emp_no emp_title_id  birth_date  first_name   last_name sex  \
# 0       473302        s0001  1953-07-25    Hideyuki    Zallocco   M
# 1       421786        s0001  1957-09-28       Xiong    Verhoeff   M
# 2       273487        s0001  1957-04-14   Christoph     Parfitt   M
# 3       246449        s0001  1958-03-23       Subbu  Bultermann   F
# 4        48085        s0001  1964-01-19  Venkatesan        Gilg   M
# ...        ...          ...         ...         ...         ...  ..
# 300019  111400        m0001  1959-11-09        Arie     Staelin   M
# 300020  111133        m0001  1955-03-16       Hauke       Zhang   M
# 300021  110085        m0001  1959-10-28        Ebru       Alpin   M
# 300022  110386        m0001  1953-10-04        Shem      Kieras   M
# 300023  111784        m0001  1956-06-14       Marjo  Giarratana   F
#
#          hire_date  salary    title
# 0       1990-04-28   40000    Staff
# 1       1987-11-26   40000    Staff
# 2       1991-06-28   56087    Staff
# ...

# %%
# final merged data
final_df=final_merge_df.groupby("emp_title_id").mean()
final_df
# Out:
#                      emp_no        salary
# emp_title_id
# e0001         252992.595373  48564.434447
# e0002         253654.345919  48535.336511
# e0003         253038.749885  48506.799871
# e0004         251811.432730  48582.896092
# m0001         110780.833333  51531.041667
# s0001         253408.503604  58465.382850
# s0002         254481.798969  58550.172704

# %%
#a histogram to visualize the most common salary ranges
final_df.hist(column="salary")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002458985B2B0>]],
#       dtype=object)

# %%
final_df=final_df.reset_index()

# %%
# a bar chart of average salary by title.
final_df.plot.bar(x="emp_title_id",y="salary")
plt.xlabel("emp_title_id")
plt.ylabel("salary")
# Out:
# Text(0, 0.5, 'salary')
